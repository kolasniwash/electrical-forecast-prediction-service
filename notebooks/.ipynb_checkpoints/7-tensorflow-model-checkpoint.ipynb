# %%
#from cloud_utils.utils import get_gcs_data, get_client, get_time_dates, gcs_load_name, get_data
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate Dataset

# %%
bucket = "ml-energy-dashboard-raw-data"
folder = 'raw-days'
client = get_client()
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-7-08ddf7e5c1ec> in <module>
#       1 bucket = "ml-energy-dashboard-raw-data"
#       2 folder = 'raw-days'
# ----> 3 client = get_client()
#
# NameError: name 'get_client' is not defined

# %%
dates = get_time_dates(90, pairs=True)
data = get_data(client, dates)
# Out:
# raw-days/es-energy-demand-20191218T2300-20191219T2300
# raw-days/es-energy-demand-20191219T2300-20191220T2300
# raw-days/es-energy-demand-20191220T2300-20191221T2300
# raw-days/es-energy-demand-20191221T2300-20191222T2300
# raw-days/es-energy-demand-20191222T2300-20191223T2300
# raw-days/es-energy-demand-20191223T2300-20191224T2300
# raw-days/es-energy-demand-20191224T2300-20191225T2300
# raw-days/es-energy-demand-20191225T2300-20191226T2300
# raw-days/es-energy-demand-20191226T2300-20191227T2300
# raw-days/es-energy-demand-20191227T2300-20191228T2300
# raw-days/es-energy-demand-20191228T2300-20191229T2300
# raw-days/es-energy-demand-20191229T2300-20191230T2300
# raw-days/es-energy-demand-20191230T2300-20191231T2300
# raw-days/es-energy-demand-20191231T2300-20200101T2300
# raw-days/es-energy-demand-20200101T2300-20200102T2300
# raw-days/es-energy-demand-20200102T2300-20200103T2300
# raw-days/es-energy-demand-20200103T2300-20200104T2300
# raw-days/es-energy-demand-20200104T2300-20200105T2300
# raw-days/es-energy-demand-20200105T2300-20200106T2300
# raw-days/es-energy-demand-20200106T2300-20200107T2300
# raw-days/es-energy-demand-20200107T2300-20200108T2300
# raw-days/es-energy-demand-20200108T2300-20200109T2300
# raw-days/es-energy-demand-20200109T2300-20200110T2300
# raw-days/es-energy-demand-20200110T2300-20200111T2300
# raw-days/es-energy-demand-20200111T2300-20200112T2300
# raw-days/es-energy-demand-20200112T2300-20200113T2300
# raw-days/es-energy-demand-20200113T2300-20200114T2300
# raw-days/es-energy-demand-20200114T2300-20200115T2300
# raw-days/es-energy-demand-20200115T2300-20200116T2300
# raw-days/es-energy-demand-20200116T2300-20200117T2300
# raw-days/es-energy-demand-20200117T2300-20200118T2300
# raw-days/es-energy-demand-20200118T2300-20200119T2300
# raw-days/es-energy-demand-20200119T2300-20200120T2300
# raw-days/es-energy-demand-20200120T2300-20200121T2300
# raw-days/es-energy-demand-20200121T2300-20200122T2300
# raw-days/es-energy-demand-20200122T2300-20200123T2300
# raw-days/es-energy-demand-20200123T2300-20200124T2300
# raw-days/es-energy-demand-20200124T2300-20200125T2300
# raw-days/es-energy-demand-20200125T2300-20200126T2300
# raw-days/es-energy-demand-20200126T2300-20200127T2300
# raw-days/es-energy-demand-20200127T2300-20200128T2300
# raw-days/es-energy-demand-20200128T2300-20200129T2300
# raw-days/es-energy-demand-20200129T2300-20200130T2300
# raw-days/es-energy-demand-20200130T2300-20200131T2300
# raw-days/es-energy-demand-20200131T2300-20200201T2300
# raw-days/es-energy-demand-20200201T2300-20200202T2300
# raw-days/es-energy-demand-20200202T2300-20200203T2300
# raw-days/es-energy-demand-20200203T2300-20200204T2300
# raw-days/es-energy-demand-20200204T2300-20200205T2300
# raw-days/es-energy-demand-20200205T2300-20200206T2300
# raw-days/es-energy-demand-20200206T2300-20200207T2300
# raw-days/es-energy-demand-20200207T2300-20200208T2300
# raw-days/es-energy-demand-20200208T2300-20200209T2300
# raw-days/es-energy-demand-20200209T2300-20200210T2300
# raw-days/es-energy-demand-20200210T2300-20200211T2300
# raw-days/es-energy-demand-20200211T2300-20200212T2300
# raw-days/es-energy-demand-20200212T2300-20200213T2300
# raw-days/es-energy-demand-20200213T2300-20200214T2300
# raw-days/es-energy-demand-20200214T2300-20200215T2300
# raw-days/es-energy-demand-20200215T2300-20200216T2300
# raw-days/es-energy-demand-20200216T2300-20200217T2300
# raw-days/es-energy-demand-20200217T2300-20200218T2300
# raw-days/es-energy-demand-20200218T2300-20200219T2300
# raw-days/es-energy-demand-20200219T2300-20200220T2300
# raw-days/es-energy-demand-20200220T2300-20200221T2300
# raw-days/es-energy-demand-20200221T2300-20200222T2300
# raw-days/es-energy-demand-20200222T2300-20200223T2300
# raw-days/es-energy-demand-20200223T2300-20200224T2300
# raw-days/es-energy-demand-20200224T2300-20200225T2300
# raw-days/es-energy-demand-20200225T2300-20200226T2300
# raw-days/es-energy-demand-20200226T2300-20200227T2300
# raw-days/es-energy-demand-20200227T2300-20200228T2300
# raw-days/es-energy-demand-20200228T2300-20200229T2300
# raw-days/es-energy-demand-20200229T2300-20200301T2300
# raw-days/es-energy-demand-20200301T2300-20200302T2300
# raw-days/es-energy-demand-20200302T2300-20200303T2300
# raw-days/es-energy-demand-20200303T2300-20200304T2300
# raw-days/es-energy-demand-20200304T2300-20200305T2300
# raw-days/es-energy-demand-20200305T2300-20200306T2300
# raw-days/es-energy-demand-20200306T2300-20200307T2300
# raw-days/es-energy-demand-20200307T2300-20200308T2300
# raw-days/es-energy-demand-20200308T2300-20200309T2300
# raw-days/es-energy-demand-20200309T2300-20200310T2300
# raw-days/es-energy-demand-20200310T2300-20200311T2300
# raw-days/es-energy-demand-20200311T2300-20200312T2300
# raw-days/es-energy-demand-20200312T2300-20200313T2300
# raw-days/es-energy-demand-20200313T2300-20200314T2300
# raw-days/es-energy-demand-20200314T2300-20200315T2300
# raw-days/es-energy-demand-20200315T2300-20200316T2300
# raw-days/es-energy-demand-20200316T2300-20200317T2300

# %% [markdown]
# Allocate train and test sets.
# Train set 75 days.
# Test set 15 days.

# %%
def load_data():
    
    path = '~/github-repos/energy-dashboard/data'
    bucket = "ml-energy-dashboard-raw-data"
    folder = 'raw-days'
    period = 90 #days
    
    try:
        train = pd.read_csv(os.path.join(path, 'train-20191219-20200302.csv'), index_col=[0], parse_dates=True)
        print('Train data loaded from local')
        
        test = pd.read_csv(os.path.join(path, 'test-20200103-20200317.csv'), index_col=[0], parse_dates=True)
        print('Test data loaded from local')
        
        print(f'Train date start {train.index.min()} end {train.index.max()}')
        print(f'Test date start {test.index.min()} end {test.index.max()}')
        
    except:
        print('Downloading data sets from cloud...')
        
        client = get_client()
        
        dates = get_time_dates(period, pairs=True)
        data = get_data(client, dates)
        
        train_days = 75
        test_days = 15
        
        train = data[:train_days*24]
        test = data[test_days*24:]
        
        print(f'Train date start {train.index.min()} end {train.index.max()}')
        print(f'Test date start {test.index.min()} end {test.index.max()}')
    
    return train, test

train, test = load_data()
# Out:
# Downloading data sets from cloud...
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# <ipython-input-12-f35d35ef43d8> in load_data()
#       8     try:
# ----> 9         train = pd.read_csv(os.path.join(path, 'train-20191219-20200302.csv'), index_col=[0], parse_dates=True)
#      10         print('Train data loaded from local')
#
# ~/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#
# ~/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#
# ~/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     879
# --> 880         self._make_engine(self.engine)
#     881
#
# ~/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#
# ~/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/ns/github-repos/energy-dashboard/data/train-20191219-20200302.csv does not exist: '/Users/ns/github-repos/energy-dashboard/data/train-20191219-20200302.csv'
#
# During handling of the above exception, another exception occurred:
#
# NameError                              Traceback (most recent call last)
# <ipython-input-12-f35d35ef43d8> in <module>
#      35     return train, test
#      36
# ---> 37 train, test = load_data()
#
# <ipython-input-12-f35d35ef43d8> in load_data()
#      19         print('Downloading data sets from cloud...')
#      20
# ---> 21         client = get_client()
#      22
#      23         dates = get_time_dates(period, pairs=True)
#
# NameError: name 'get_client' is not defined

# %% [markdown]
# ## Preprocessing Pipeline

# %%
def transform_hours(series):
    df = pd.DataFrame()

    df['year'] = series.index.year
    df['month'] = series.index.month
    df['day'] = series.index.day
    df['hours'] = series.index.hour
    df['loads'] = series.values

    date_list = pd.to_datetime(df.loc[:,['year', 'month', 'day']], format='%Y-%m-%d', errors='ignore')
    df = df.set_index(pd.DatetimeIndex(date_list, name='date'))
    df = df.drop(['year', 'month', 'day'], axis=1)
    df = df.drop_duplicates()
    df = df.pivot(columns='hours', values='loads')
    
    return df

train_df = transform_hours(train)
train_df
# Out:
# hours            0        1        2        3        4        5        6   \
# date
# 2019-12-19  27080.0  25146.0  24001.0  23364.0  23199.0  24026.0  26782.0
# 2019-12-20  26722.0  24815.0  23242.0  22733.0  22628.0  23157.0  25702.0
# 2019-12-21  25221.0  23305.0  21976.0  21194.0  20862.0  20930.0  21758.0
# 2019-12-22  23435.0  21641.0  20456.0  19757.0  19414.0  19342.0  19787.0
# 2019-12-23  22716.0  21058.0  20024.0  19359.0  19278.0  20099.0  22218.0
# ...             ...      ...      ...      ...      ...      ...      ...
# 2020-02-27  26554.0  24847.0  23699.0  23324.0  23493.0  24126.0  26808.0
# 2020-02-28  26522.0      NaN  23720.0  23273.0  23283.0  23924.0  26253.0
# 2020-02-29  26178.0  24712.0  23324.0  22717.0  22428.0  22310.0  22895.0
# 2020-03-01  24306.0  22848.0  21638.0  20833.0  20431.0  20616.0  21035.0
# 2020-03-02  24359.0  22644.0  21709.0  21432.0  21573.0  22336.0  25463.0
#
# hours            7        8        9   ...       14       15       16  \
# date                                   ...
# 2019-12-19  31151.0  33548.0  34510.0  ...  34143.0  33651.0  33567.0
# 2019-12-20  29672.0  32120.0  32893.0  ...  31985.0  31260.0  30972.0
# 2019-12-21  23135.0  24656.0  27007.0  ...  28329.0  27192.0  26632.0
# 2019-12-22  20774.0  21922.0  23931.0  ...  26289.0  25002.0  24205.0
# 2019-12-23  25172.0  27565.0  29428.0  ...  28871.0  28028.0  27722.0
# ...             ...      ...      ...  ...      ...      ...      ...
# 2020-02-27  30863.0  32533.0  33365.0  ...  31580.0  30914.0  30475.0
# 2020-02-28  29455.0  30926.0  32175.0  ...  30657.0  29785.0  29279.0
# 2020-02-29  23909.0  25274.0  27946.0  ...  28673.0  27383.0  26595.0
# 2020-03-01  21434.0  22076.0  24313.0  ...  26791.0  25465.0  24576.0
# 2020-03-02  29200.0  31353.0  32759.0  ...  32143.0  31420.0  30818.0
#
# hours            17       18       19       20       21       22       23
# date
# 2019-12-19  33975.0  35023.0  35208.0  35364.0  34426.0  31925.0  28793.0
# 2019-12-20  31394.0  32459.0  32613.0  32470.0  31590.0  29526.0  27092.0
# 2019-12-21  26859.0  28321.0  28752.0  29107.0  28826.0  27403.0  25465.0
# 2019-12-22  24454.0  26399.0  27170.0  27988.0  28158.0  26958.0  24821.0
# 2019-12-23  27978.0  29534.0  29733.0  29892.0  29686.0  28012.0  25543.0
# ...             ...      ...      ...      ...      ...      ...      ...
# 2020-02-27  30241.0  30352.0  32785.0  33986.0  33209.0  30768.0  28108.0
# 2020-02-28  28919.0  28926.0  31272.0  32178.0  31771.0  29601.0  27444.0
# 2020-02-29  26376.0  26731.0  28763.0  29649.0  29607.0  28193.0  26209.0
# 2020-03-01  24265.0  25052.0  27950.0  29592.0  29384.0  28285.0  26502.0
# 2020-03-02  30579.0  30885.0  33246.0  34548.0  33501.0  30950.0  28059.0
#
# [75 rows x 24 columns]

# %%
#fill nans
def fill_nans(df):
    return df.interpolate(method='linear', axis=0)
train_df = fill_nans(train_df)

# %%
def normalize_df(df, test=None, scaler=None):
    
    if test:
        data_normd = scaler.transform(df)
    else:
        #normalize the dataset for working with the lstm nn
        scaler = MinMaxScaler().fit(df.values)
        data_normd = scaler.transform(df.values)
    
    #return as dataframe
    df = pd.DataFrame(data_normd, index=df.index, columns=df.columns)
    
    return df, scaler

train_df, scaler = normalize_df(train_df)
train_df
# Out:
# hours             0         1         2         3         4         5   \
# date
# 2019-12-19  0.793395  0.804486  0.805574  0.783925  0.778595  0.807865
# 2019-12-20  0.750715  0.762544  0.705797  0.701592  0.704880  0.705243
# 2019-12-21  0.571769  0.571211  0.539372  0.500783  0.476891  0.442253
# 2019-12-22  0.358846  0.360365  0.339556  0.313283  0.289956  0.254724
# 2019-12-23  0.273128  0.286493  0.282766  0.261352  0.272399  0.344119
# ...              ...       ...       ...       ...       ...       ...
# 2020-02-27  0.730687  0.766599  0.765874  0.778706  0.816550  0.819674
# 2020-02-28  0.726872  0.758046  0.768634  0.772051  0.789440  0.795820
# 2020-02-29  0.685861  0.749493  0.716577  0.699504  0.679060  0.605220
# 2020-03-01  0.462685  0.513305  0.494939  0.453680  0.421250  0.405172
# 2020-03-02  0.469003  0.487456  0.504272  0.531837  0.568681  0.608290
#
# hours             6         7         8         9   ...        14        15  \
# date                                                ...
# 2019-12-19  0.845328  0.833026  0.813535  0.791029  ...  0.735953  0.757546
# 2019-12-20  0.747066  0.739056  0.737501  0.705396  ...  0.604295  0.619290
# 2019-12-21  0.388227  0.323718  0.340078  0.393687  ...  0.381246  0.384064
# 2019-12-22  0.208898  0.173709  0.194505  0.230790  ...  0.256787  0.257430
# 2019-12-23  0.430079  0.453142  0.494968  0.521898  ...  0.414313  0.432404
# ...              ...       ...       ...       ...  ...       ...       ...
# 2020-02-27  0.847694  0.814728  0.759491  0.730392  ...  0.579586  0.599283
# 2020-02-28  0.797198  0.725268  0.673926  0.667373  ...  0.523275  0.534000
# 2020-02-29  0.491675  0.372895  0.372983  0.443415  ...  0.402233  0.395108
# 2020-03-01  0.322446  0.215643  0.202705  0.251019  ...  0.287414  0.284203
# 2020-03-02  0.725321  0.709067  0.696662  0.698300  ...  0.613934  0.628542
#
# hours             16        17        18        19        20        21  \
# date
# 2019-12-19  0.770933  0.786820  0.764997  0.708214  0.691208  0.696669
# 2019-12-20  0.622512  0.634951  0.604104  0.546491  0.503979  0.493923
# 2019-12-21  0.374285  0.368108  0.344440  0.305871  0.286407  0.296325
# 2019-12-22  0.235472  0.226596  0.223833  0.207279  0.214013  0.248570
# 2019-12-23  0.436628  0.433951  0.420557  0.367007  0.337194  0.357807
# ...              ...       ...       ...       ...       ...       ...
# 2020-02-27  0.594086  0.567108  0.471888  0.557211  0.602057  0.609665
# 2020-02-28  0.525681  0.489320  0.382405  0.462919  0.485088  0.506863
# 2020-02-29  0.372169  0.339688  0.244666  0.306556  0.321472  0.352159
# 2020-03-01  0.256692  0.215475  0.139307  0.255889  0.317785  0.336217
# 2020-03-02  0.613704  0.586996  0.505334  0.585940  0.638416  0.630540
#
# hours             22        23
# date
# 2019-12-19  0.721805  0.719088
# 2019-12-20  0.538002  0.550421
# 2019-12-21  0.375345  0.389093
# 2019-12-22  0.341250  0.325235
# 2019-12-23  0.422004  0.396827
# ...              ...       ...
# 2020-02-27  0.633160  0.651165
# 2020-02-28  0.543748  0.585325
# 2020-02-29  0.435872  0.462866
# 2020-03-01  0.442921  0.491919
# 2020-03-02  0.647104  0.646306
#
# [75 rows x 24 columns]

# %%
def split_sequences(sequences, n_steps, extra_lag=False, long_lag_step=7, max_step=30, idx=0, multivar=False):
    """
    Modified based on content by Jason Brownlee from MachineLearningMastery.
    
    n_step - is the number of consecutive past steps from the target day to construct
    long_lag_step - is the size of the trailing lag beyond the n_steps. Ie. if n_steps is 3, and long_lag_step is 7 will return day -1, -2, -3, -7, -14 etc to max_step
    idx - is the starting index for the first slice
    multivari - true if the input data has multiple variable structure. false for univariate
    """
    
    #if not adding extra lag features adjust max_step and n_steps to aling
    if not extra_lag:
        max_step=n_steps
        n_steps+=1
        
    
    X, y = list(), list()
    for i in range(len(sequences)):
        
        # find the end of this pattern
        #end_ix = i + n_steps
        end_ix = i + max_step
        
        #create a list with the indexes we want to include in each sample
        slices = [x for x in range(end_ix-1,end_ix-n_steps, -1)] + [y for y in range(end_ix-n_steps, i, -long_lag_step)]
        
        #reverse the slice indexes
        slices = list(reversed(slices))
        
        # check if we are beyond the dataset
        if end_ix > len(sequences)-1:
            break


        # gather input and output parts of the pattern
        seq_x = sequences[slices, :]
        seq_y = sequences[end_ix, :]

        X.append(seq_x)
        y.append(seq_y)
        
    X = np.array(X)
    y = np.array(y)
    
    if multivar:
        #unstack the 3rd dimension and select the first element(energy load)
        y = y[:,idx]
    
    return X, y

n_steps = 7
long_lag_step = 7

X_train, Y_train = split_sequences(train_df.values, 
                       n_steps, 
                       extra_lag=True, 
                       long_lag_step=long_lag_step, 
                       max_step=30, 
                       idx=0, 
                       multivar=False)
print(f'Transformed train dataset shape {train_df.shape}')
print(f'X_train shape. No sample days {X_train.shape[0]} No features {X_train.shape[1]} No hours {X_train.shape[2]}')
print(f'Y_train shape. No sample days {Y_train.shape[0]} No target values {X_train.shape[1]}')
X_train[:1], Y_train[:1]
# Out:
# Transformed train dataset shape (75, 24)
# X_train shape. No sample days 45 No features 10 No hours 24
# Y_train shape. No sample days 45 No target values 10
# (array([[[0.57176919, 0.57121135, 0.53937163, 0.50078288, 0.4768913 ,
#           0.44225319, 0.38822673, 0.32371815, 0.34007774, 0.39368744,
#           0.3926918 , 0.35568632, 0.33805979, 0.35264676, 0.38124581,
#           0.38406384, 0.37428506, 0.36810827, 0.34444026, 0.30587062,
#           0.28640745, 0.29632542, 0.37534477, 0.38909271],
#          [0.42274678, 0.40737456, 0.38306823, 0.35464509, 0.32674929,
#           0.31400567, 0.29551451, 0.26069001, 0.29694904, 0.34708468,
#           0.35400132, 0.32271032, 0.29103155, 0.29723841, 0.32469038,
#           0.3316179 , 0.31771906, 0.30826714, 0.3154493 , 0.30406332,
#           0.29954066, 0.32177581, 0.41242721, 0.42330193],
#          [0.73986648, 0.70704511, 0.6624162 , 0.61143006, 0.59178931,
#           0.53920642, 0.4508234 , 0.36997268, 0.3858687 , 0.44103162,
#           0.46638007, 0.45443952, 0.41829139, 0.42648531, 0.47099018,
#           0.47571412, 0.44566461, 0.43006767, 0.44321034, 0.43475009,
#           0.44303552, 0.48391478, 0.59661355, 0.66931086],
#          [0.99737721, 0.97997973, 0.94281583, 0.89418058, 0.85954041,
#           0.77657062, 0.61750523, 0.50066713, 0.50572387, 0.5742202 ,
#           0.602403  , 0.57539035, 0.54017488, 0.53288583, 0.56738454,
#           0.5614664 , 0.5307138 , 0.50791409, 0.53049699, 0.55347127,
#           0.56000518, 0.61817272, 0.72709163, 0.81358453],
#          [0.80424416, 0.77660922, 0.72538451, 0.67223382, 0.63361735,
#           0.58419934, 0.46492585, 0.35364381, 0.33422076, 0.38013028,
#           0.42041446, 0.42723141, 0.40948836, 0.43231467, 0.48441218,
#           0.47316989, 0.441089  , 0.42041777, 0.47922942, 0.52972703,
#           0.57359125, 0.62567915, 0.75697211, 0.79335647],
#          [0.75560324, 0.74569184, 0.74681215, 0.71607516, 0.75935967,
#           0.80125177, 0.90155582, 0.93347735, 0.96560354, 0.96430652,
#           0.94400353, 0.92187136, 0.88715585, 0.87416829, 0.8785309 ,
#           0.88417948, 0.8868108 , 0.89255663, 0.92400853, 0.94378661,
#           0.95853012, 0.97612239, 0.9737205 , 0.99058007],
#          [0.99976156, 0.97706538, 0.97765216, 0.98186326, 0.97818229,
#           0.97933396, 1.        , 1.        , 1.        , 0.97754594,
#           0.93022487, 0.89996504, 0.85306629, 0.83300948, 0.83930206,
#           0.85555684, 0.85592542, 0.87666961, 0.9095758 , 0.91954381,
#           0.93465744, 0.95181584, 0.9515783 , 0.96460089],
#          [0.99165474, 0.96578814, 0.96345471, 0.96046451, 0.95533178,
#           0.94709495, 0.96879265, 0.96422899, 0.9552207 , 0.9341736 ,
#           0.89489638, 0.86232813, 0.82890228, 0.81322499, 0.81794887,
#           0.82843761, 0.8290437 , 0.84060018, 0.86477159, 0.88078026,
#           0.88995277, 0.91907349, 0.92598835, 0.92989588],
#          [0.93705293, 0.95324379, 0.94702248, 0.94206681, 0.94435838,
#           0.95181861, 0.96933855, 0.95615986, 0.94819232, 0.9166446 ,
#           0.86711861, 0.82661384, 0.77980622, 0.76588353, 0.77749985,
#           0.7895802 , 0.79432624, 0.81141512, 0.83816516, 0.85024305,
#           0.86569192, 0.8880469 , 0.904076  , 0.92057511],
#          [0.9620887 , 0.96046629, 0.95333246, 0.95511482, 0.95055513,
#           0.94319792, 0.95368938, 0.93214308, 0.91746978, 0.89053646,
#           0.83454586, 0.79189   , 0.76013234, 0.74969087, 0.75517052,
#           0.76350179, 0.75737817, 0.75210356, 0.76085592, 0.7681042 ,
#           0.74826939, 0.77866743, 0.81703953, 0.87902826]]]),
#  array([[0.94575584, 0.93626457, 0.89746286, 0.8308977 , 0.78814872,
#          0.71457251, 0.58647985, 0.46896245, 0.47792982, 0.5480591 ,
#          0.59198633, 0.58284782, 0.55973059, 0.56892186, 0.59477762,
#          0.5703134 , 0.53494624, 0.51915269, 0.51223645, 0.51514396,
#          0.49744452, 0.52194738, 0.6130095 , 0.6754586 ]]))

# %%
def process_pipeline(series, test_df=False, scaler=None):
    
    
    df = transform_hours(series)
    df = fill_nans(df)
    
    dataset='train'
    
    if test_df:
        assert scaler is not None, 'must pass in minmax scaler object when test is True'
        
        df, scaler = normalize_df(df, test=True, scaler=scaler)
        
        dataset='test'
    else:
        df, scaler = normalize_df(df)
    
    X, Y = split_sequences(df.values, 
                       n_steps, 
                       extra_lag=True, 
                       long_lag_step=long_lag_step, 
                       max_step=30, 
                       idx=0, 
                       multivar=False)
    
    print(f'Transformed train dataset shape {df.shape}')
    print(f'X_{dataset} shape. No sample days {X.shape[0]} No features {X.shape[1]} No hours {X.shape[2]}')
    print(f'Y_{dataset} shape. No sample days {Y.shape[0]} No target values {X.shape[1]}')
    
    return X, Y, scaler

X_train, Y_train, scaler = process_pipeline(train)
# Out:
# Transformed train dataset shape (75, 24)
# X_train shape. No sample days 45 No features 10 No hours 24
# Y_train shape. No sample days 45 No target values 10

# %%
X_train, Y_train, scaler = process_pipeline(train)
# Out:
# Transformed train dataset shape (75, 24)
# X_train shape. No sample days 45 No features 10 No hours 24
# Y_train shape. No sample days 45 No target values 10

# %%
X_test, Y_test, scaler = process_pipeline(test, test_df=True, scaler=scaler)
# Out:
# Transformed train dataset shape (75, 24)
# X_test shape. No sample days 45 No features 10 No hours 24
# Y_test shape. No sample days 45 No target values 10

# %% [markdown]
# ## Define LSTM model

# %%
def lstm_parallel_out(n_lags, n_hours, cells=50, learning_rate=5e-3):
    
    #define the model
    model = keras.models.Sequential()
    model.add(keras.layers.LSTM(cells, activation='relu', return_sequences=True, input_shape=(n_lags, n_hours)))
    model.add(keras.layers.LSTM(int(cells/2), activation='relu'))
    model.add(keras.layers.Dense(n_hours))
    model.add(keras.layers.Dropout(0.2))
    
    #define the learning rate
    optimizer = keras.optimizers.Adam(lr=learning_rate)
    
    #compile model
    model.compile(optimizer=optimizer, loss='mae')
    
    return model

lstm_model = lstm_parallel_out(X_train.shape[1], X_train.shape[-1])
lstm_model.fit(X_train, Y_train, epochs=200, verbose=1)
# Out:
# Train on 45 samples
# Epoch 1/200
# 45/45 [==============================] - 2s 44ms/sample - loss: 0.6017
# Epoch 2/200
# 45/45 [==============================] - 0s 787us/sample - loss: 0.5823
# Epoch 3/200
# 45/45 [==============================] - 0s 730us/sample - loss: 0.4765
# Epoch 4/200
# 45/45 [==============================] - 0s 732us/sample - loss: 0.4387
# Epoch 5/200
# 45/45 [==============================] - 0s 752us/sample - loss: 0.4144
# Epoch 6/200
# 45/45 [==============================] - 0s 757us/sample - loss: 0.3716
# Epoch 7/200
# 45/45 [==============================] - 0s 1ms/sample - loss: 0.3384
# Epoch 8/200
# 45/45 [==============================] - 0s 845us/sample - loss: 0.3163
# Epoch 9/200
# 45/45 [==============================] - 0s 700us/sample - loss: 0.2993
# Epoch 10/200
# 45/45 [==============================] - 0s 699us/sample - loss: 0.2886
# Epoch 11/200
# 45/45 [==============================] - 0s 709us/sample - loss: 0.2745
# Epoch 12/200
# 45/45 [==============================] - 0s 579us/sample - loss: 0.2663
# Epoch 13/200
# 45/45 [==============================] - 0s 829us/sample - loss: 0.2430
# Epoch 14/200
# 45/45 [==============================] - 0s 541us/sample - loss: 0.2445
# Epoch 15/200
# 45/45 [==============================] - 0s 616us/sample - loss: 0.2313
# Epoch 16/200
# 45/45 [==============================] - 0s 592us/sample - loss: 0.2360
# Epoch 17/200
# 45/45 [==============================] - 0s 555us/sample - loss: 0.2186
# Epoch 18/200
# 45/45 [==============================] - 0s 599us/sample - loss: 0.2106
# Epoch 19/200
# 45/45 [==============================] - 0s 560us/sample - loss: 0.2281
# Epoch 20/200
# 45/45 [==============================] - 0s 573us/sample - loss: 0.2197
# Epoch 21/200
# 45/45 [==============================] - 0s 558us/sample - loss: 0.2214
# Epoch 22/200
# 45/45 [==============================] - 0s 570us/sample - loss: 0.2291
# Epoch 23/200
# 45/45 [==============================] - 0s 574us/sample - loss: 0.2190
# Epoch 24/200
# 45/45 [==============================] - 0s 527us/sample - loss: 0.2366
# Epoch 25/200
# 45/45 [==============================] - 0s 672us/sample - loss: 0.2114
# Epoch 26/200
# 45/45 [==============================] - 0s 575us/sample - loss: 0.2309
# Epoch 27/200
# 45/45 [==============================] - 0s 520us/sample - loss: 0.2132
# Epoch 28/200
# 45/45 [==============================] - 0s 558us/sample - loss: 0.2039
# Epoch 29/200
# 45/45 [==============================] - 0s 530us/sample - loss: 0.1592
# Epoch 185/200
# 45/45 [==============================] - 0s 520us/sample - loss: 0.1687
# Epoch 186/200
# 45/45 [==============================] - 0s 525us/sample - loss: 0.1518
# Epoch 187/200
# 45/45 [==============================] - 0s 544us/sample - loss: 0.1498
# Epoch 188/200
# 45/45 [==============================] - 0s 520us/sample - loss: 0.1585
# Epoch 189/200
# 45/45 [==============================] - 0s 509us/sample - loss: 0.1567
# Epoch 190/200
# 45/45 [==============================] - 0s 524us/sample - loss: 0.1517
# Epoch 191/200
# 45/45 [==============================] - 0s 540us/sample - loss: 0.1631
# Epoch 192/200
# 45/45 [==============================] - 0s 512us/sample - loss: 0.1533
# Epoch 193/200
# 45/45 [==============================] - 0s 573us/sample - loss: 0.1442
# Epoch 194/200
# 45/45 [==============================] - 0s 510us/sample - loss: 0.1352
# Epoch 195/200
# 45/45 [==============================] - 0s 503us/sample - loss: 0.1454
# Epoch 196/200
# 45/45 [==============================] - 0s 528us/sample - loss: 0.1608
# Epoch 197/200
# 45/45 [==============================] - 0s 500us/sample - loss: 0.1524
# Epoch 198/200
# 45/45 [==============================] - 0s 510us/sample - loss: 0.1430
# Epoch 199/200
# 45/45 [==============================] - 0s 516us/sample - loss: 0.1455
# Epoch 200/200
# 45/45 [==============================] - 0s 544us/sample - loss: 0.1557

# %% [markdown]
# ## Evaluate Model

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def plot_hourly_error(Y_true, Y_preds):
    #calcuate the hourly errors
    hourly_errors = [mean_absolute_percentage_error(Y_true[:][hour], Y_preds[:][hour]) for hour in range(Y_true.shape[1])]

    hourly_errors = pd.Series(hourly_errors)

    print(mean_absolute_percentage_error(Y_true, Y_preds))
    
    hourly_errors.plot()
    plt.xlabel('Hour of the Day')
    plt.ylabel('MAPE %')

# %%
#make training predictions
y_train_preds = lstm_model.predict(X_train, verbose=1)

plot_hourly_error(Y_train, y_train_preds)
# Out:
# 45/45 [==============================] - 0s 203us/sample
# 19.065119106902273

# %% [markdown]
# ## Make predictions on the test set

# %%
X_test, Y_test, _ = process_pipeline(test, test=True, scaler=scaler)
# Out:
# Transformed train dataset shape (75, 24)
# X_test shape. No sample days 45 No features 10 No hours 24
# Y_test shape. No sample days 45 No target values 10

# %%
Y_test.shape
# Out:
# (45, 24)

# %%
y_test_preds = lstm_model.predict(X_test)

plot_hourly_error(Y_test, y_test_preds)
# Out:
# inf
# /Users/ns/github-repos/energy-dashboard/venv-energy-dashboard/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
y_test_preds
# Out:
# array([[0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987],
#        [0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987],
#        [0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987],
#        ...,
#        [0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987],
#        [0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987],
#        [0.2205368 , 0.22548814, 0.19736075, ..., 0.1018566 , 0.1755507 ,
#         0.18884987]], dtype=float32)
